# %%
import random
import string
from words import words
def get_valid_word(words):
    word = random.choice(words)
    while '-' in word or ' ' in word:
        word = random.choice(words)
    return word

def hangman():
    word = get_valid_word(words)
    word_letters = set(word)
    alphabet = set(string.ascii_uppercase)
    used_letters = set()
    lives = 6
    while len(word_letters) > 0 and lives > 0:
        print('You have, lives ', lives, ' left used these letters', ''.join(used_letters))
        word_list = [letter if letter in used_letters else '-' for letter in word]
        print('Current word: ', ' '.join(word_list))
        user_letter = input('Guess a letter: ').upper()
        if user_letter in alphabet - used_letters:
            used_letters.add(user_letter)
            if user_letter in word_letters:
                word_letters.remove(user_letter)
            else:
                lives = lives - 1
                print('letter is not in word')
        elif user_letter in user_letter:
            print('You already used the letter. Please try again')
        else:
            print('Invalid character type')
    if lives == 0:
        print('Sorry, you\'ve die. The word was ', word)
    else:
        print('You\' guessed the word', word, '!!')
hangman()
# Out:
# You have used these letters
# Current word:  - - - - - -
# You have used these letters R
# Current word:  - - - - - -
# You already used the letter. Please try again
# You have used these letters R
# Current word:  - - - - - -
# You have used these letters TR
# Current word:  - - - - - -
# You have used these letters TUR
# Current word:  - - - - - -
# You have used these letters TUGR
# Current word:  - - - - - -
# You have used these letters UGRTS
# Current word:  - - - - - -
# You have used these letters UFGRTS
# Current word:  - - - - - -
# You already used the letter. Please try again
# You have used these letters UFGRTS
# Current word:  - - - - - -
# You already used the letter. Please try again
# You have used these letters UFGRTS
# Current word:  - - - - - -
# You already used the letter. Please try again
# You have used these letters UFGRTS
# Current word:  - - - - - -
# You already used the letter. Please try again
# You have used these letters UFGRTS
# ...
